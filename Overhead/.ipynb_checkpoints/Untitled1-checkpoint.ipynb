# %%
import matplotlib.pyplot as plt
import pandas as pd

# Corrected and updated overhead data (all values in µs)
data = {
    "Tasks": list(range(2, 17)),
    "Meas µs": [0.12, 0.18, 0.21, 0.41, 0.93, 1.21, 1.28, 1.36, 1.41, 1.49, 1.53, 1.66, 1.75, 2.02, 2.50],
    "σMeas":   [0.09, 0.07, 0.04, 0.13, 0.15, 0.08, 0.07, 0.12, 0.08, 0.12, 0.12, 0.14, 0.11, 0.09, 0.08],
    "Ctrl µs": [3.23, 4.55, 6.30, 7.50, 9.19, 10.49, 12.28, 13.97, 15.31, 16.99, 18.13, 20.09, 21.26, 22.77, 25.26],
    "σCtrl":   [0.72, 0.65, 1.08, 0.83, 0.67, 0.70, 1.61, 1.33, 1.98, 1.49, 1.09, 1.69, 0.99, 1.38, 1.91],
    "Act µs":  [0.00, 0.01, 0.04, 0.17, 0.24, 0.36, 0.65, 1.02, 1.11, 1.25, 1.30, 1.76, 1.98, 2.24, 2.85],
    "σAct":    [0.00, 0.10, 0.20, 0.38, 0.43, 0.48, 0.54, 0.60, 0.49, 0.48, 0.46, 0.62, 0.51, 0.45, 0.48]
}

df = pd.DataFrame(data)

# Create 1x3 subplot
fig, axs = plt.subplots(1, 3, figsize=(12, 3))

# Plot 1: Measurement Overhead (µs)
axs[0].plot(df["Tasks"], df["Meas µs"], marker='d', color='green')
axs[0].set_xlabel("Tasks\n(a) Response time Measurement", fontsize=14)
axs[0].set_ylabel("Overhead (us)", fontsize=14)
axs[0].spines['top'].set_visible(False)
axs[0].spines['right'].set_visible(False)
axs[0].tick_params(labelsize=14)

# Plot 2: Controller Overhead (µs)
axs[1].plot(df["Tasks"], df["Ctrl µs"], marker='*', color='orange')
axs[1].set_xlabel("Tasks\n(b) Controller", fontsize=14)
axs[1].set_ylabel("Overhead (us)", fontsize=14)
axs[1].spines['top'].set_visible(False)
axs[1].spines['right'].set_visible(False)
axs[1].tick_params(labelsize=14)

# Plot 3: Actuator Overhead (µs)
axs[2].plot(df["Tasks"], df["Act µs"], marker='o', color='blue')
axs[2].set_xlabel("Tasks\n \n (c) Actuator", fontsize=14)
axs[2].set_ylabel("Overhead (us)", fontsize=14)
axs[2].spines['top'].set_visible(False)
axs[2].spines['right'].set_visible(False)
axs[2].tick_params(labelsize=14)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig("overhead_updated.pdf")
plt.show()
